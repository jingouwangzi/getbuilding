# %%
f = open("123.json",'r')

# %%
import json

# %%
aaa = json.load(f)

# %%
print (aaa)
# Out:
# {'displayFieldName': 'photoid', 'fieldAliases': {'objectid': 'objectid', 'photoid': 'photoid', '建筑名称': '建筑名称', '建筑地址': '建筑地址', '地上层数': '地上层数', '地下层数': '地下层数', '基底面积': '基底面积', '建筑面积': '建筑面积', '建筑结构': '建筑结构', '建筑用途': '建筑用途', '分层_jr': '分层_jr', '建面_jr': '建面_jr', '分层_ja': '分层_ja', '建面_ja': '建面_ja', '分层_jb': '分层_jb', '建面_jb': '建面_jb', '分层_jm': '分层_jm', '建面_jm': '建面_jm', '分层_jw': '分层_jw', '建面_jw': '建面_jw', '分层_js': '分层_js', '建面_js': '建面_js', '分层_ju': '分层_ju', '建面_ju': '建面_ju', '分层_ff': '分层_ff', '建面_ff': '建面_ff', '备注': '备注', '行政区': '行政区', '环线范围': '环线范围', 'shape_Length': 'shape_Length', 'shape_Area': 'shape_Area'}, 'geometryType': 'esriGeometryPolygon', 'spatialReference': {'wkid': 2435, 'latestWkid': 2435}, 'fields': [{'name': 'objectid', 'type': 'esriFieldTypeOID', 'alias': 'objectid'}, {'name': 'photoid', 'type': 'esriFieldTypeString', 'alias': 'photoid', 'length': 254}, {'name': '建筑名称', 'type': 'esriFieldTypeString', 'alias': '建筑名称', 'length': 254}, {'name': '建筑地址', 'type': 'esriFieldType
# ...

# %%
print (type(aaa))
# Out:
# <class 'dict'>

# %%
for a in aaa:
    print (a)
# Out:
# displayFieldName
# fieldAliases
# geometryType
# spatialReference
# fields
# features
# exceededTransferLimit

# %%
bbb = aaa['features']

# %%
print (bbb[0])
# Out:
# {'attributes': {'objectid': 16, 'photoid': ' ', '建筑名称': '城中村-山后毕村', '建筑地址': '喻家湖路', '地上层数': 2, '地下层数': 0, '基底面积': 105.08874848, '建筑面积': 210.17749696, '建筑结构': '混', '建筑用途': 'JR4', '分层_jr': 'JR4', '建面_jr': 210.17749696, '分层_ja': ' ', '建面_ja': 0, '分层_jb': ' ', '建面_jb': 0, '分层_jm': ' ', '建面_jm': 0, '分层_jw': ' ', '建面_jw': 0, '分层_js': ' ', '建面_js': 0, '分层_ju': ' ', '建面_ju': 0, '分层_ff': ' ', '建面_ff': 0, '备注': ' ', '行政区': '洪山区', '环线范围': '三环内', 'shape_Length': 41.10463541994148, 'shape_Area': 105.0887385128946}, 'geometry': {'rings': [[[541180, 3379448], [541171, 3379437], [541169, 3379446], [541180, 3379448]]]}}

# %%
print (type(bbb))
# Out:
# <class 'list'>

# %%
i=1
for a in bbb:
    for b in a['geometry']['rings']:
        
        for j in b:
            print (i,',',j[0],',',j[1])
    i+=1
# Out:
# 1 , 541180 , 3379448
# 1 , 541171 , 3379437
# 1 , 541169 , 3379446
# 1 , 541180 , 3379448
# 2 , 541299 , 3379329
# 2 , 541300 , 3379343
# 2 , 541307 , 3379333
# 2 , 541299 , 3379329
# 3 , 541257 , 3379433
# 3 , 541270 , 3379429
# 3 , 541260 , 3379424
# 3 , 541257 , 3379433
# 4 , 541150 , 3379432
# 4 , 541138 , 3379423
# 4 , 541138 , 3379432
# 4 , 541150 , 3379432
# 5 , 541201 , 3379405
# 5 , 541203 , 3379416
# 5 , 541213 , 3379414
# 5 , 541201 , 3379405
# 6 , 541372 , 3379472
# 6 , 541364 , 3379475
# 6 , 541369 , 3379486
# 6 , 541372 , 3379472
# 7 , 541436 , 3379520
# 7 , 541438 , 3379534
# 7 , 541444 , 3379528
# 7 , 541436 , 3379520
# 8 , 541316 , 3379358
# 8 , 541324 , 3379369
# 8 , 541326 , 3379360
# 8 , 541316 , 3379358
# 9 , 541266 , 3379507
# 9 , 541275 , 3379514
# 9 , 541274 , 3379504
# 9 , 541266 , 3379507
# 10 , 541357 , 3379422
# 10 , 541364 , 3379415
# 10 , 541353 , 3379410
# 10 , 541357 , 3379422
# 11 , 541265 , 3379410
# 11 , 541273 , 3379421
# 11 , 541275 , 3379413
# ...
